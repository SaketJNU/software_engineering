# %% [markdown]
# **Read CSV from Pandas**

# %%
import pandas as pd

# %%
import os

# %%
csv_file_path = "raw_data"
file_list = os.listdir(csv_file_path)
file_list
# Out:
# ['10,11-16']

# %%
file_name = csv_file_path + "/" + file_list[0]
file_name
# Out:
# 'raw_data/10,11-16'

# %%
csv_data = pd.read_csv(file_name)
csv_data
# Out:
#                   timestamp     amount   price symbol
# 0       2016-10-24 10:33:23  -0.727285  655.93    BTC
# 1       2016-10-24 10:33:23  -0.869754  655.93    BTC
# 2       2016-10-24 10:33:23  -0.869672  655.93    BTC
# 3       2016-10-24 10:33:23  -9.145700  655.93    BTC
# 4       2016-10-24 10:33:23  -0.869628  655.93    BTC
# 5       2016-10-24 10:33:23  -0.869603  655.93    BTC
# 6       2016-10-24 10:33:23  -0.058757  655.93    BTC
# 7       2016-10-24 10:38:58  -1.520000  655.93    BTC
# 8       2016-10-24 10:38:58  -1.690000  655.93    BTC
# 9       2016-10-24 10:43:05  -1.811400  655.51    BTC
# 10      2016-10-24 10:44:16  -0.152532  655.50    BTC
# 11      2016-10-24 10:51:02  -4.110000  655.51    BTC
# 12      2016-10-24 10:54:11  -0.060000  655.50    BTC
# 13      2016-10-24 11:00:05  -4.079800  655.97    BTC
# 14      2016-10-24 11:01:02  -0.467600  656.28    BTC
# 15      2016-10-24 11:01:04  -0.401317  656.28    BTC
# ...

# %%
csv_data.columns
# Out:
# Index(['timestamp', 'amount', 'price', 'symbol'], dtype='object')

# %%
column_index = csv_data.columns 
key_names = column_index.values.tolist()
key_names
# Out:
# ['timestamp', 'amount', 'price', 'symbol']

# %%
price = csv_data[key_names[2]]
type(price)
# Out:
# pandas.core.series.Series
